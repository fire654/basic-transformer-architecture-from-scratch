# %%
from adapters import *

# %% [markdown]
# # 参数

# %%
vocab_size=8000
context_length=256
d_model=768
d_ff=3072
theta=1000
num_layers=6
num_heads=12
device=torch.device('cuda')
dtype=torch.bfloat16
batch_size=32
lr=3e-4
weight_decay=0.01
epoch=1000
grad_clip=1.0

# %% [markdown]
#  BPRtokenizer

# %%
vocab,merge=read_vocab_merges('BPE')
tokenizer=get_tokenizer(vocab,merge)

# %% [markdown]
# 模型和优化器

# %%
model=TransformerLM(vocab_size,d_model,num_layers,num_heads,d_ff,context_length,theta,device,torch.float32)
adam=get_adamw_cls()
optimizer=adam(params=model.parameters(),lr=0.0001)

# %% [markdown]
# 导入训练后的参数

# %%
run_load_checkpoint('state_dict.pt',model,optimizer)
# Out:
# 1

# %% [markdown]
# 提示词

# %%
prompt=r""
num_lst=tokenizer.encode(prompt)

# %% [markdown]
# 测试

# %%
print(tokenizer.decode(generate_with_sliding_window(model,num_lst,0.5,context_length,1000,device)))
# Out:
#  one and that thou hast done;
# For I have often heard thy name of length,
# And mine only stand upon my weapon,
# 'Tis more than all the eyes of the world:
# I think there is no soldier.
#
# VIRGILIA:
# My lord and son.
#
# CORIOLANUS:
# That I, an't like you, sir:
# Let's before a doublet in the substance of the business
# As are as fast as an exchanges, where I hearing,
# My house slf stand on Romeo's mean, soon,
# The son of Rome; chaste is entering yours,
# To wakest and wail it in their age;
# The parents live, whose children thou hast butcher'd,
# Old winty, once from their power of justice,
# That they have led since they on then.
#
# LORD ROSS:
# And repents but theirs,--
#
# EDWARD:
# Dazzleds fair for a while, lord clouds.
#
# RICHARD:
# I do thou behold my study with all blood.
#
# QUEEN ELIZABETH:
# The life of such death too much mind the king.
#
# KING RICHARD III:
# Be patient, by the holy man, at the measure
# Hath grown interruption of the devil' death,
# The commons make the deadly very sleep,
# The dangerous sleep from her, when it did look
# With wine they steel, the hearer brother's
# Thy wife and children thou dest know with one showers:
# I'll prove him, and give thee armour to his age,
# From the place I am a poor countenanced.
#
# DUKE OF YORK:
# Blind strong and fair, your noble cousin's death?
#
# DUCHESS OF YORK:
# I will, my lord: the day before I so.
#
# KING RICHARD III:
# Well, bring them to run, Tyrrel, am I dead.
# Go, remember this true wrongs, and they
# Should still therein will be deliver'd.
#
# RICHARD:
# Then, defend me not, for I have more struck
# Than accessful following thee for my pater fair:
# I do repent me, and therefore for better:
# I do remember all my love to love,
# And aid thee that exatate t
